# %%
file=open("f\\ sample.txt","w")
write()
file.write("hello,world!\n")
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8f0fc6aa513d> in <module>
# ----> 1 file=open("f\\ sample.txt","w")
#       2 write()
#       3 file.write("hello,world!\n")
#       4 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'f\\ sample.txt'
