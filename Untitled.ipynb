# %%
open() with'w'mode
file=open("students.txt","w")
file.write("name:alice,roll no:1,grade:a\n")
file.close()
# Out:
#   File "<ipython-input-1-fefd3813d592>", line 1
#     open() with'w'mode
#               ^
# SyntaxError: invalid syntax

# %%
write()
file.write("hello,world!\n")
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8da9c9411623> in <module>
# ----> 1 write()
#       2 file.write("hello,world!\n")
#       3 file.close()
#
# NameError: name 'write' is not defined
